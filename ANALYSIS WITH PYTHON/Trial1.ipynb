# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#1 Understanding Data

# %%
data = pd.read_csv("cardata.csv")
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
data.shape
# Out:
# (301, 9)

# %%
data.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Car_Name          98
# Year              16
# Selling_Price    156
# Present_Price    147
# Kms_Driven       206
# Fuel_Type          3
# Seller_Type        2
# Transmission       2
# Owner              3
# dtype: int64

# %%
data["Seller_Type"].unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
# 2 cleaning of the data

# %%
data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
#3 Relationship analysis

# %%
data.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
# Convert object variables to categorical type
object_vars = data.select_dtypes(include='object').columns
data[object_vars]= data[object_vars].astype('category')

# %%
# Calculate the correlation matrix for numerical variables
numeric_vars = data.select_dtypes(include=['float64', 'int64']).columns
corr_matrix = data[numeric_vars].corr()
corr_matrix
# Out:
#                    Year  Selling_Price  Present_Price  Kms_Driven     Owner
# Year           1.000000       0.236141      -0.047584   -0.524342 -0.182104
# Selling_Price  0.236141       1.000000       0.878983    0.029187 -0.088344
# Present_Price -0.047584       0.878983       1.000000    0.203647  0.008057
# Kms_Driven    -0.524342       0.029187       0.203647    1.000000  0.089216
# Owner         -0.182104      -0.088344       0.008057    0.089216  1.000000

# %%
# Plot the correlation matrix as a heatmap using seaborn
sns.heatmap(corr_matrix, annot=True, cmap='cool')
# Out:
# <Axes: >

# %%
data.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
sns.pairplot(data)

# %%
sns.relplot(x='Year',y='Selling_Price',hue='Kms_Driven',data = data)

# %%
sns.displot(data['Present_Price'], bins = 20)
# bins can be used for distplot and displot removes space btn columus

# %%
sns.catplot(x = 'Year', kind='box',data = data)

# %% [markdown]
# WORKING WITH DATASET TWO IE WHO_COVID19.CSV

# %%
data2 = pd.read_csv("who_covid19.csv")
data2
# Out:
#                          Name       WHO Region  Cases - cumulative total  \
# 0                      Global              NaN                 196553009
# 1    United States of America         Americas                  34564448
# 2                       India  South-East Asia                  31572344
# 3                      Brazil         Americas                  19797086
# 4          Russian Federation           Europe                   6242066
# ..                        ...              ...                       ...
# 233              Saint Helena           Africa                         0
# 234                   Tokelau  Western Pacific                         0
# 235                     Tonga  Western Pacific                         0
# 236              Turkmenistan           Europe                         0
# 237                    Tuvalu  Western Pacific                         0
#
#      Cases - cumulative total per 100000 population  \
# ...

# %%
data2.nunique()
# Out:
# Name                                                            238
# WHO Region                                                        7
# Cases - cumulative total                                        224
# Cases - cumulative total per 100000 population                  224
# Cases - newly reported in last 7 days                           192
# Cases - newly reported in last 7 days per 100000 population     207
# Cases - newly reported in last 24 hours                         147
# Deaths - cumulative total                                       196
# Deaths - cumulative total per 100000 population                 205
# Deaths - newly reported in last 7 days                           99
# Deaths - newly reported in last 7 days per 100000 population    100
# Deaths - newly reported in last 24 hours                         58
# dtype: int64

# %%
data2.isnull().sum()
# Out:
# Name                                                            0
# WHO Region                                                      1
# Cases - cumulative total                                        0
# Cases - cumulative total per 100000 population                  1
# Cases - newly reported in last 7 days                           0
# Cases - newly reported in last 7 days per 100000 population     1
# Cases - newly reported in last 24 hours                         0
# Deaths - cumulative total                                       0
# Deaths - cumulative total per 100000 population                 1
# Deaths - newly reported in last 7 days                          0
# Deaths - newly reported in last 7 days per 100000 population    1
# Deaths - newly reported in last 24 hours                        0
# dtype: int64

# %%
data2.describe()
# Out:
#        Cases - cumulative total  \
# count              2.380000e+02
# mean               1.651706e+06
# std                1.313683e+07
# min                0.000000e+00
# 25%                5.014750e+03
# 50%                5.182250e+04
# 75%                3.774782e+05
# max                1.965530e+08
#
#        Cases - cumulative total per 100000 population  \
# count                                      237.000000
# mean                                      3834.947955
# std                                       4170.716536
# min                                          0.000000
# 25%                                        277.650000
# 50%                                       2287.840000
# 75%                                       6671.150000
# max                                      18967.190000
#
#        Cases - newly reported in last 7 days  \
# count                           2.380000e+02
# mean                            3.361281e+04
# ...

# %%
data2.shape
# Out:
# (238, 12)
